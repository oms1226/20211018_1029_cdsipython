# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(10)
plt.plot(x)

# %%
x = np.arange(10)
y = x ** 2
plt.plot(x, y)

# %%
x = np.arange(10)
y = x ** 2
plt.plot(x, y, 'ro')

# %%
x = np.arange(10)
plt.plot(x, x*2, 'b-', x, x**2, 'r--', x, x**3, 'go')
# Out:
# [<matplotlib.lines.Line2D at 0x1634a03ecc0>,
#  <matplotlib.lines.Line2D at 0x1634a03ee48>,
#  <matplotlib.lines.Line2D at 0x1634a03ef98>]

# %%
x = np.arange(10)
plt.plot(x, x*2, 'b-')
plt.plot(x, x**2, 'r--')
plt.plot(x, x**3, 'go')

# %%
x = np.arange(10)
plt.plot(x, x*2, 'b-', x, x**2, 'r--', x, x**3, 'go')
plt.xlabel("money")
plt.ylabel("time")
plt.title("time for money")
# Out:
# Text(0.5, 1.0, 'time for money')

# %%
x = np.arange(10)
y = x ** 2
plt.plot(x, y)
plt.xlim(2, 5)
plt.ylim(5, 20)
# Out:
# (5, 20)

# %%
x = np.arange(10)
y = x ** 2
y2 = x*5 + 2
plt.plot(x, y, 'b', label='first')
plt.plot(x, y2, 'r', label='second')
plt.legend(loc='upper right')

# %%
x = np.arange(10)
y = x ** 2

plt.plot(x, y)

plt.annotate('here', xy=(4, 16),
             xytext=(5,20),
             arrowprops={'color':'green'})

plt.text(7, 70, '$y=x^2$')
# Out:
# Text(7, 70, '$y=x^2$')

# %%
x = np.arange(10)
plt.subplot(2, 2, 1)
plt.plot(x, x**2)
plt.subplot(2, 2, 2)
plt.plot(x, x*5)
plt.subplot(223)
plt.plot(x, np.sin(x))
plt.subplot(224)
plt.plot(x, np.cos(x))

# %%
x = np.arange(50)
y = x+np.random.randn(50) * 10
magnitude = np.random.randint(1, 100, 50)
category = np.random.randint(0, 5, 50)
plt.scatter(x, y, s=magnitude, c=category)

# %%
names = ['A', 'B', 'C']
values = [50, 30, 100]
plt.subplot(1, 2, 1)
plt.bar(names, values)
plt.subplot(1, 2, 2)
plt.barh(names, values)
# Out:
# <BarContainer object of 3 artists>

# %%
x = np.arange(10)
y = x ** 2
plt.figure(figsize=(20, 5))
plt.plot(x, y)

# %%
x = 100 + 15 * np.random.randn(10000)
n, bins, patches = plt.hist(x, 50)

# %%
from PIL import Image

img = Image.open('tkv.jpg')
plt.imshow(img)

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading https://files.pythonhosted.org/packages/1c/37/48895b3402fed66489e4176065b8bee89573e67377be6830ed8ab58f9cdb/opencv_python-4.5.1.48-cp36-cp36m-win_amd64.whl (34.9MB)
# Requirement already satisfied: numpy>=1.13.3 in c:\anaconda3\envs\py369\lib\site-packages (from opencv-python) (1.16.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.1.48

# %%
import cv2

img = cv2.imread('tkv.jpg')
plt.imshow(img[:,:,::-1])

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

x = np.linspace(0, 14, 100)
y1 = np.sin(x)
y2 = 2 * np.sin(x+0.5)
y3 = 3 * np.sin(x+1.0)
y4 = 4 * np.sin(x+1.5)

plt.figure(figsize=(10, 6))
plt.plot(x, y1, x, y2, x, y3, x, y4)
plt.show()

# %%
sns.set_style("dark")
plt.figure(figsize=(10, 6))
plt.plot(x, y1, x, y2, x, y3, x, y4)
plt.show()

# %%
sns.set_style("whitegrid")
sns.despine(offset=10)
plt.figure(figsize=(10, 6))
plt.plot(x, y1, x, y2, x, y3, x, y4)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

sns.set_style("whitegrid")

tips = sns.load_dataset("tips")
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(8, 6))
sns.boxplot(x=tips["total_bill"])
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x="day", y="total_bill", hue="smoker", data=tips, palette="Set3")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.swarmplot(x="day", y="total_bill", data=tips, color=".5")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x="day", y="total_bill", data=tips)
sns.swarmplot(x="day", y="total_bill", data=tips, color=".25")
plt.show()

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(8, 6))
sns.lmplot(x="total_bill", y="tip", data=tips, size=7)
plt.show()
# Out:
# C:\anaconda3\lib\site-packages\seaborn\regression.py:574: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips, size=7)
plt.show()
# Out:
# C:\anaconda3\lib\site-packages\seaborn\regression.py:574: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips, palette="Set1",size=7)
plt.show()
# Out:
# C:\anaconda3\lib\site-packages\seaborn\regression.py:574: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
flights = sns.load_dataset("flights")
flights.head(5)
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights = flights.pivot("month", "year", "passengers")
flights.head(5)
# Out:
# year      1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January    112   115   145   171   196   204   242   284   315   340   360
# February   118   126   150   180   196   188   233   277   301   318   342
# March      132   141   178   193   236   235   267   317   356   362   406
# April      129   135   163   181   235   227   269   313   348   348   396
# May        121   125   172   183   229   234   270   318   355   363   420
#
# year      1960
# month
# January    417
# February   391
# March      419
# April      461
# May        472

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(flights)
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(flights, annot=True, fmt="d")
plt.show()

# %%
sns.set(style="ticks")
iris = sns.load_dataset("iris")
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
sns.pairplot(iris)
plt.show()

# %%
sns.pairplot(iris, hue='species')
plt.show()

# %%
sns.pairplot(iris, vars=['sepal_width', 'sepal_length'])
plt.show()

# %%
sns.pairplot(iris, x_vars=['sepal_width', 'sepal_length'],
            y_vars=['petal_width', 'petal_length'])
plt.show()
